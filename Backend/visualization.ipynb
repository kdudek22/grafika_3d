# %%
import matplotlib.pyplot as plt
import json

# %%
with open("mazda_data.json", "r") as f:
    data = json.load(f)

# %%
x = [d["x"] for d in data]
y = [d["y"] for d in data]
z = [d["z"] for d in data]

plt.scatter(x, y)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(len(data["z"]))
#
# TypeError: list indices must be integers or slices, not str
